# %%
from pathlib import Path
import pandas as pd
import pygwalker as pyg
import matplotlib.pyplot as plt
import numpy as np

from lib import core, analysis
from lib.core import Core
from lib import analysis

# %matplotlib widget

# %% [markdown]
# # Vue d'ensemble
#
# Ce dashboard donne une vue d'ensemble sur les progrès en terme d'analyse et de développement de solutions d'algorithmes de hachage flous.

# %%
data = Path("./data")
core = Core(data)

# %% [markdown]
# Les algorithmes actuellements supportés sont :

# %%
core.runners()
# Out:
# ['lzjd', 'tlsh', 'nilsimsa', 'ssdeep', 'sdhash']

# %% [markdown]
# Les benchmarks qui ont été développé sont :

# %%
core.benchmarks()
# Out:
# ['image', 'noise', 'noise_images', 'text']

# %%
def run(runner, benchmark):
    df = core.run([runner], [benchmark])
    return analysis.pretty(df)

# %% [markdown]
# Configuration de base pour visualiser les résultats d'un algorithme donné.

# %%
vis_spec_single_runner = r"""{"config":[{"config":{"defaultAggregated":false,"geoms":["circle"],"coordSystem":"generic","limit":-1,"timezoneDisplayOffset":0},"encodings":{"dimensions":[{"fid":"suffix","name":"suffix","basename":"suffix","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"ref","name":"ref","basename":"ref","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mods","name":"mods","basename":"mods","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"bench","name":"bench","basename":"bench","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"alt","name":"alt","basename":"alt","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"algo","name":"algo","basename":"algo","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mod","name":"mod","basename":"mod","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"modval","name":"modval","basename":"modval","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"gw_mea_key_fid","name":"Measure names","analyticType":"dimension","semanticType":"nominal"}],"measures":[{"fid":"dist","name":"dist","basename":"dist","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"gw_count_fid","name":"Row count","analyticType":"measure","semanticType":"quantitative","aggName":"sum","computed":true,"expression":{"op":"one","params":[],"as":"gw_count_fid"}},{"fid":"gw_mea_val_fid","name":"Measure values","analyticType":"measure","semanticType":"quantitative","aggName":"sum"}],"rows":[{"fid":"dist","name":"dist","basename":"dist","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0}],"columns":[{"fid":"suffix","name":"suffix","basename":"suffix","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mod","name":"mod","basename":"mod","semanticType":"nominal","analyticType":"dimension","offset":0}],"color":[{"fid":"modval","name":"modval","basename":"modval","semanticType":"nominal","analyticType":"dimension","offset":0}],"opacity":[],"size":[],"shape":[],"radius":[],"theta":[],"longitude":[],"latitude":[],"geoId":[],"details":[{"fid":"alt","name":"alt","basename":"alt","semanticType":"nominal","analyticType":"dimension","offset":0}],"filters":[{"fid":"bench","name":"bench","basename":"bench","semanticType":"nominal","analyticType":"dimension","offset":0,"rule":{"type":"one of","value":["image"]}}],"text":[]},"layout":{"showActions":false,"showTableSummary":false,"stack":"stack","interactiveScale":false,"zeroScale":true,"size":{"mode":"full","width":320,"height":200},"format":{},"geoKey":"name","resolve":{"x":false,"y":false,"color":false,"opacity":false,"shape":false,"size":false}},"visId":"gw_DCxV","name":"Image - Format impact"},{"config":{"defaultAggregated":false,"geoms":["circle"],"coordSystem":"generic","limit":-1,"timezoneDisplayOffset":0},"encodings":{"dimensions":[{"fid":"suffix","name":"suffix","basename":"suffix","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"ref","name":"ref","basename":"ref","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mods","name":"mods","basename":"mods","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"bench","name":"bench","basename":"bench","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"alt","name":"alt","basename":"alt","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"algo","name":"algo","basename":"algo","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mod","name":"mod","basename":"mod","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"modval","name":"modval","basename":"modval","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"gw_mea_key_fid","name":"Measure names","analyticType":"dimension","semanticType":"nominal"}],"measures":[{"fid":"dist","name":"dist","basename":"dist","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0},{"fid":"gw_count_fid","name":"Row count","analyticType":"measure","semanticType":"quantitative","aggName":"sum","computed":true,"expression":{"op":"one","params":[],"as":"gw_count_fid"}},{"fid":"gw_mea_val_fid","name":"Measure values","analyticType":"measure","semanticType":"quantitative","aggName":"sum"}],"rows":[{"fid":"dist","name":"dist","basename":"dist","analyticType":"measure","semanticType":"quantitative","aggName":"sum","offset":0}],"columns":[{"fid":"suffix","name":"suffix","basename":"suffix","semanticType":"nominal","analyticType":"dimension","offset":0},{"fid":"mod","name":"mod","basename":"mod","semanticType":"nominal","analyticType":"dimension","offset":0}],"color":[{"fid":"modval","name":"modval","basename":"modval","semanticType":"nominal","analyticType":"dimension","offset":0}],"opacity":[],"size":[],"shape":[],"radius":[],"theta":[],"longitude":[],"latitude":[],"geoId":[],"details":[{"fid":"alt","name":"alt","basename":"alt","semanticType":"nominal","analyticType":"dimension","offset":0}],"filters":[{"fid":"bench","name":"bench","basename":"bench","semanticType":"nominal","analyticType":"dimension","offset":0,"rule":{"type":"one of","value":["text"]}}],"text":[]},"layout":{"showActions":false,"showTableSummary":false,"stack":"stack","interactiveScale":false,"zeroScale":true,"size":{"mode":"full","width":320,"height":200},"format":{},"geoKey":"name","resolve":{"x":false,"y":false,"color":false,"opacity":false,"shape":false,"size":false}},"visId":"gw_bwdB","name":"Text"}],"chart_map":{},"workflow_list":[{"workflow":[{"type":"filter","filters":[{"fid":"bench","rule":{"type":"one of","value":["image"]}}]},{"type":"view","query":[{"op":"raw","fields":["suffix","mod","modval","alt","dist"]}]}]},{"workflow":[{"type":"filter","filters":[{"fid":"bench","rule":{"type":"one of","value":["text"]}}]},{"type":"view","query":[{"op":"raw","fields":["suffix","mod","modval","alt","dist"]}]}]}],"version":"0.4.9.13"}"""
def basic_single_runner_analysis(*runners):
    df = analysis.pretty(core.run(runners, core.benchmarks()))
    df = analysis.long(df)
    return pyg.walk(df, spec=vis_spec_single_runner)

# %% [markdown]
# #### Indicators
# We used for comparisons between the algorithms 5 indicators:
# - False positive rate: the fraction of pairs of dissimilar files juged similar by our algorithm
# - Recall: = 1 - False negative rate, the fraction of pairs of similar files juged similar by our algorithm
# - Precision: the fraction of pairs of similar files among the pairs juged similars by our algorithm
# - Global precision: the fraction of pairs of files that were correctly juged by our algorithm among every pair
# - False negative rate: the fraction of pairs of similar files juged dissimilar by our algorithm
#
# They are calculated with the class Indicators(df_similar, df_non_similar, threshold) where df_similar (resp df_non_similar) is the dataframe containing the results of the algorithm on a benchmark with pairs of similar files (resp non_similar).

# %%
def indicators_based_analysis(runner, bench_similar, bench_non_similar, suffix=None):
    pos = run(runner, bench_similar) 
    neg = run(runner, bench_non_similar) 

    if suffix:
        pos = pos[pos['suffix'] == suffix]
        neg = neg[neg['suffix'] == suffix]

    return analysis.indicators_based_analysis_on_dfs(pos,neg)

# %% [markdown]
# # sdhash performances

# %%
basic_single_runner_analysis('sdhash')
# Out:
# Running ('sdhash',) with benchs ['image', 'noise', 'noise_images', 'text']
# []
# []
# [(WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-02.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-03.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-04.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-05.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-06.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-07.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-08.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-09.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-10.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-11.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-12.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-13.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-14.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-15.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-16.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-17.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-18.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-03.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-04.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-05.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-06.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-07.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-08.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-09.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-10.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-11.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-12.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-13.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-14.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-15.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-16.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-17.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-18.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-04.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-05.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-06.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-07.png')), (WindowsPath('benchmarks/noise_images/03 ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 basic_single_runner_analysis('sdhash')
#
# Cell In[6], line 3, in basic_single_runner_analysis(*runners)
#       2 def basic_single_runner_analysis(*runners):
# ----> 3     df = analysis.pretty(core.run(runners, core.benchmarks()))
#       4     df = analysis.long(df)
#       5     return pyg.walk(df, spec=vis_spec_single_runner)
#
# File c:\Users\defir\psc\lib\core.py:196, in Core.run(self, runners, benchs, bypass_cache, recompute_cache)
#     193 if not bypass_cache and not recompute_cache:
#     194     runner = Core.CachedRunner(self.root, self._cache, runner)
# --> 196 runner.run(bench)
#     197 rows.extend([
#     198     (runner.id(), bench.id(),
#     199      e.ref, e.alt, e.dist, vars(e))
#     200     for e in bench._entries.values()
#     201 ])
#     203 if recompute_cache:
#
# File c:\Users\defir\psc\lib\core.py:227, in Core.CachedRunner.run(self, bench)
#     225 new_pairs = bench.pairs(absolute = False, skip_computed=True)
#     226 print(new_pairs)
# --> 227 if new_pairs: self.runner.run(bench)
#     228 new_results = [(ref,alt,bench.attrs(ref,alt).dist) for ref,alt in new_pairs]
#     229 self.cache.save_results(self.runner.id(), new_results)
#
# File c:\Users\defir\psc\lib\core.py:37, in HashDistRunner.run(self, bench)
#      34 pairs = bench.pairs(absolute=True, skip_computed=True)
#      35 for ref,alt in pairs:
#      36     bench.attrs(ref,alt).dist = self.distance(
# ---> 37         self._get_hash(ref),
#      38         self._get_hash(alt),
#      39     )
#
# File c:\Users\defir\psc\lib\core.py:49, in HashDistRunner._get_hash(self, path)
#      47 def _get_hash(self, path):
#      48     if path not in self._cache:
# ---> 49         self._cache[path] = self.hash(path)
#      50     return self._cache[path]
#
# File c:\Users\defir\psc\runners\sdhash.py:17, in Sdhash.hash(self, path)
#      16 def hash(self, path):
# ---> 17     return subprocess.check_output([SDHASH_BIN, str(path)], text=True)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# OSError: [WinError 193] %1 n’est pas une application Win32 valide

# %% [markdown]
# ## Short texts (~30 Ko)

# %%
threshold_sdhash_text, indicators_sdhash_text = indicators_based_analysis('sdhash', 'text', 'noise')
# Out:
# Running ['sdhash'] with benchs ['text']
# []
# Running ['sdhash'] with benchs ['noise']
# []
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for key, value in vars(indicators_sdhash_text).items():
    print(f"{key}: {value}")
# Out:
# fp_len: 55
# fn_len: 200
# fp_count: 0
# fn_count: 1
# tn_count: 55
# tp_count: 199
# fn_rate: 0.005
# fp_rate: 0.0
# global_precision: 0.996078431372549
# precision: 1.0
# recall: 0.995

# %% [markdown]
# ## Images

# %% [markdown]
# ### .bmp files

# %%
threshold_sdhash_bmp, indicators_sdhash_bmp = indicators_based_analysis('sdhash', 'image', 'noise_images', suffix="bmp")
# Out:
# Running ['sdhash'] with benchs ['image']
# []
# Running ['sdhash'] with benchs ['noise_images']
# [(WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-02.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-03.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-04.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-05.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-06.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-07.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-08.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-09.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-10.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-11.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-12.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-13.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-14.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-15.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-16.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-17.png')), (WindowsPath('benchmarks/noise_images/01.ref.png'), WindowsPath('benchmarks/noise_images/01.alt-18.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-03.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-04.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-05.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-06.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-07.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-08.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-09.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-10.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-11.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-12.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-13.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-14.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-15.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-16.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-17.png')), (WindowsPath('benchmarks/noise_images/02.ref.png'), WindowsPath('benchmarks/noise_images/02.alt-18.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-04.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-05.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-06.png')), (WindowsPath('benchmarks/noise_images/03.ref.png'), WindowsPath('benchmarks/noise_images/03.alt-07.png')), (WindowsPath('benchmarks/noise_images/03 ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 threshold_sdhash_bmp, indicators_sdhash_bmp = indicators_based_analysis('sdhash', 'image', 'noise_images', suffix="bmp")
#
# Cell In[7], line 3, in indicators_based_analysis(runner, bench_similar, bench_non_similar, suffix)
#       1 def indicators_based_analysis(runner, bench_similar, bench_non_similar, suffix=None):
#       2     pos = run(runner, bench_similar)
# ----> 3     neg = run(runner, bench_non_similar)
#       5     if suffix:
#       6         pos = pos[pos['suffix'] == suffix]
#
# Cell In[5], line 2, in run(runner, benchmark)
#       1 def run(runner, benchmark):
# ----> 2     df = core.run([runner], [benchmark])
#       3     return analysis.pretty(df)
#
# File c:\Users\defir\psc\lib\core.py:196, in Core.run(self, runners, benchs, bypass_cache, recompute_cache)
#     193 if not bypass_cache and not recompute_cache:
#     194     runner = Core.CachedRunner(self.root, self._cache, runner)
# --> 196 runner.run(bench)
#     197 rows.extend([
#     198     (runner.id(), bench.id(),
#     199      e.ref, e.alt, e.dist, vars(e))
#     200     for e in bench._entries.values()
#     201 ])
#     203 if recompute_cache:
#
# File c:\Users\defir\psc\lib\core.py:227, in Core.CachedRunner.run(self, bench)
#     225 new_pairs = bench.pairs(absolute = False, skip_computed=True)
#     226 print(new_pairs)
# --> 227 if new_pairs: self.runner.run(bench)
#     228 new_results = [(ref,alt,bench.attrs(ref,alt).dist) for ref,alt in new_pairs]
#     229 self.cache.save_results(self.runner.id(), new_results)
#
# File c:\Users\defir\psc\lib\core.py:37, in HashDistRunner.run(self, bench)
#      34 pairs = bench.pairs(absolute=True, skip_computed=True)
#      35 for ref,alt in pairs:
#      36     bench.attrs(ref,alt).dist = self.distance(
# ---> 37         self._get_hash(ref),
#      38         self._get_hash(alt),
#      39     )
#
# File c:\Users\defir\psc\lib\core.py:49, in HashDistRunner._get_hash(self, path)
#      47 def _get_hash(self, path):
#      48     if path not in self._cache:
# ---> 49         self._cache[path] = self.hash(path)
#      50     return self._cache[path]
#
# File c:\Users\defir\psc\runners\sdhash.py:17, in Sdhash.hash(self, path)
#      16 def hash(self, path):
# ---> 17     return subprocess.check_output([SDHASH_BIN, str(path)], text=True)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.11-windows-x86_64-none\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# OSError: [WinError 193] %1 n’est pas une application Win32 valide

# %%
for key,value in vars(indicators_sdhash_bmp).items():
    print(f"{key}:{value}")
# Out:
# fp_len:153
# fn_len:162
# fp_count:69
# fn_count:78
# tn_count:84
# tp_count:84
# fn_rate:0.48148148148148145
# fp_rate:0.45098039215686275
# global_precision:0.5333333333333333
# precision:0.5490196078431373
# recall:0.5185185185185185

# %% [markdown]
# ### .jpg files

# %%
threshold_sdhash_jpg, indicators_sdhash_jpg = indicators_based_analysis('sdhash', 'image', 'noise_images', suffix="jpg")
# Out:
# Running ['ssdeep'] with benchs ['image']
# Running ['ssdeep'] with benchs ['noise_images']
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for key, value in vars(indicators_sdhash_jpg).items():
    print(f"{key}:{value}")
# Out:
# fp_len:190
# fn_len:180
# fp_count:86
# fn_count:93
# tn_count:104
# tp_count:87
# fn_rate:0.5166666666666667
# fp_rate:0.45263157894736844
# global_precision:0.5162162162162162
# precision:0.5028901734104047
# recall:0.48333333333333334

# %% [markdown]
# ### .png files

# %%
threshold_sdhash_png, indicators_sdhash_png = indicators_based_analysis('sdhash', 'image', 'noise_images', suffix="png")
# Out:
# Running ['ssdeep'] with benchs ['image']
# Running ['ssdeep'] with benchs ['noise_images']
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for key, value in vars(indicators_sdhash_png).items():
    print(f"{key}:{value}")
# Out:
# fp_len:153
# fn_len:162
# fp_count:74
# fn_count:80
# tn_count:79
# tp_count:82
# fn_rate:0.49382716049382713
# fp_rate:0.48366013071895425
# global_precision:0.5111111111111111
# precision:0.5256410256410257
# recall:0.5061728395061729
